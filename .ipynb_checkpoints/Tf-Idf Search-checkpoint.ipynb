# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
import operator

# %% [markdown]
# ### Load Data

# %%
col_list = ["Pageurl", "Title", "Manufacturer", "Model Name"]
dataset = pd.read_csv("marketing_sample_for_ebay_com-ebay_com_product__20210101_20210331__30k_data.csv", usecols=col_list)

# %% [markdown]
# ### Data Cleaning

# %%
dataset['Title']=[str(entry).lower() for entry in dataset['Title']]

# %%
dataset['Title'] = dataset['Title'].replace(to_replace='[!"#$%&\'()*+,/:;<=>?@[\\]^_`{|}~]', value=' ', regex=True)
dataset['Title'] = dataset['Title'].replace(to_replace='-', value=' ', regex=True)
dataset['Title'] = dataset['Title'].replace(to_replace='  ', value=' ', regex=True)

# %%
dataset.head()
# Out:
#                                              Pageurl  \
# 0  https://www.ebay.com/p/7024512090?iid=16461748...
# 1  https://www.ebay.com/itm/Apple-Airpods-Pro-wit...
# 2  https://www.ebay.com/p/238211749?iid=174232921...
# 3  https://www.ebay.com/itm/Nintendo-wii-console-...
# 4  https://www.ebay.com/itm/Fossil-smart-watch/16...
#
#                                                Title  \
# 0  samsung galaxy note 8 6gb ram 64gb dual sim un...
# 1  apple airpods pro with wireless charging case ...
# 2  apple ipad pro 1st gen. 64gb wi fi  4g unlocke...
# 3    nintendo wii console fit board and games bundle
# 4                                 fossil smart watch
#
#                                         Manufacturer  \
# 0                                            Samsung
# 1  Apple Airpods Pro with wireless charging case ...
# 2                                              Apple
# 3    Nintendo wii console fit board and games bundle
# 4                                 Fossil smart watch
#
#                                           Model Name
# 0                               Samsung Galaxy Note8
# 1  Apple Airpods Pro with wireless charging case ...
# 2                    Apple iPad Pro (1st Generation)
# 3    Nintendo wii console fit board and games bundle
# 4                                 Fossil smart watch

# %%
vocabulary = set()

for doc in dataset['Title']:
    vocabulary.update(doc.split(' '))
    
vocabulary = list(vocabulary)
# Out:
# ['', 'gazingsure', 'o7i2', 'w4', 'prestine', '2.5in', 'slps00235', 'doqus', 'camera\xa0', 'surely', 'supaboy', 'speakerrsmo', '2053d', '82', '100nas', 'lautsprecher', '1672', '8hq', 'c810', 'bh079', 'solare', 'eligible', 'adler', 'apricot', 'kilometer', 'ni', 'exeze', 'cbk', 'era', 'detektor', 'sonic', 'wedcam', 'maxstrata', '70', '525', 'betrieb', 'death', 'tvin0250bk', 'néon', '5520', '9e', 'kinderuhr', 'staubstecker', 'sofie', 'tu250x', 'teddy', 'nutella', 'ele', 'mv19m2', 'conbrov', 'einseitiges', '367927u', 'a605', '72ir', '2835smd', '11', 'jax', 'flat', '371', 'm07', 'vernee', 'end', '£299', 'palladium', 'a30', 'panja', 'padded', 'x1126ah', '060566083', 'c2n', 'bh528', '5230', 's905w', 'sp0500aw', 'un', 'fs930', 'shadoks', 'no.1734', '6led', '2082', '5rb', 'zoneplayer', 'megaman', 'ec', 'sirocco', '66149', 'retroilluminata', '2900k', 'mp062ll', 'tsuyokiss', '6.35mm', 'l25', 'receivh3', 'sun', 'glpx', 'bac', 'c71kw', 'btn200', 'geräuschunterdrückung', 'earpieces', '6.72in', 'caster', '3004b', 't200', 'mt9k2b', 'dummies', 'h0', '00513a', 'camera！', 'iqpanel', 'mondschein', 'n9519', 'kit.', '1.4inch', 'kragen', 'qe75q900tst', '2game', 'kazerai', '2544v', 'campana', 'lm2596s', 'montiert', 'jl10', 'scheletro', 'sbloccato', 'm58', 'fashion', '1.44in', 's160g', 'ifrogz', 'numérique', 'j108i', 'belial', 'e9p0106', 'caoutchouc', 'memorex', '131ft', 'инструкции.', 'ct9a03w23f1', 'scoche', 'speakers.', 'bois', 'digit.', 'roped', 'vieta', 'vemer', 'shc2', 'qled', 'monogatari', '888a', 'itunes', '399', 'do1', 'v11', 'xiaomi', 'spugna', 'm00m3ll', 'fierce', '02120', 'x6ftfz', 'watch', 'a3919011', 'rdge', '30371', 'gently', 'vanpower', 'b04', 'bundles', 'schutzaufbewah', 'brunhilde', 'ga01334', 'litre', 'raider', 'schwa', 'euro', 'mag420w1', 'pods', 'o1e1', 'alles', '\xa0great', '1453', 'scorpio', 'iwatch', '40lm', 'deltazeal', 'guardians', 'jeff', 'schlüsselbund', 'relojes', 'h820', '50000', 'shipping\xa0', '18w', 't1c', '22776', 'electromédicos', 'pentium', '771', 'audioeingang', 'rowboat', 'красный', 'a162', 'popcorn', 'yuntab', '1x6', 'bilancia', 'runners', 'etc', 'aire', 'halifax', 'nxd', 'elipsal', 'amoled🌟', 'classified', 'rm102', 'mdr', 'se215dybl', 'bsinger', 'campfire', '15.6', 'teal', 'wonderswan', 'runnin', 'rudder', '10µf', 'ae2mod', '29740', '66', 'prusa', 's152', 'cp3', 'esi', 'hang', 't68i', 'ov9726', 'a32', 'gold7.1', 'npng', 'd01100', 'luce', 'teste', 'aircraft', '4sm', 'magnifi', 'd...', '070159', 'sd5', 'combiner', 'tracker', '👍', 'gekan', 'max', 'nib', 'gps.', 'private', 'w5w', 'intertek', 'bnrv300', 'rsu11337789', 'new...', 'hj3135273', '2013', 'u1f0', '60397', 'sigma', 'cdrom', '9790', 'italian', 'trucker', 'handgehalten', 'frisco', '2500c', 'a1396', 'o7s4', 'vorverstärker', 'miss', 'motorradhelm', 'mb100h', 'hj5668720', 'helix', 'bambola', 'ax', 'unterhaltung', 'hd1080p', 'zx110nc', 'claude', 'leadcool', 'eva', 'cable.gold', 'phast', 'zkcreation', 'ninja', 'x5bt', 'unopended', 'goddess', 'rechange', 'inkpad', '349d', 'cigarette', 'aluminiumgehäuse', 'srs', 'prologue', 'monitktp', 'shades', 'blutdrucküberwachung', 'doppelhorn', 'e274', 'furniture', 'sdm632', 'repros', 'angebotspaket', 'duty', 'option', 'r810', 'rain', 'install', 'c3215', 'la100s', 'field', 'translation', 'matchbox', '32198', 'nuband', 'allarme', 'nos', 'kokkia', 'sportkopfhörer', 'mkgo', 'fantec', 'b02', 'pdf', 'cm75', 'co', 'w7r5', 'unbrnutzt', 'rg280', 'circle', 'wb02', 'b741sagok', 'broches', 'durchmesser', 'tennis.', '12in', 'simply', '425a', 'burnt', 'тон', 'sb95sa', 'whole', 'm04', 'green', '5001', 'lion', 'axial', '180x130mm', 'blueto', 'pink\xa0', 'xv', 'k512', '12ghz', 'engenharia', 'ed64', 'chargement', 'cmht1382', 'j6s', '52.8x52mm', 'bobo', 'schlafmonitor', 'a2o9', 'x410tk', 'hc66', 'individual', 'sada', 'bizarre', 'hammer', 'y8c5', 'k0n8', '1661', 'shoestring', 'oshanzu', 'handfree', '753', '3ghz', '7.5v', 'cm70', '2201332', '1526', '001bk', 'a17', 'tokyo', 'xt1941', 'mijods', 'domestic', 'cintre', 'crs', '7.5m', '8341', 'watchdog',  ...
